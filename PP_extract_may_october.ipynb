# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import xarray as xr
import glob
import os

# --------------------------------------------------
# Paths
# --------------------------------------------------
SILO_DIR = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/combined_climate"
OUT_DIR  = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/combined_climate_growing_season/Climate_variables"
os.makedirs(OUT_DIR, exist_ok=True)

# Climate variables to keep
CLIMATE_VARS = [
    "monthly_rain",
    "max_temp",
    "min_temp",
    "radiation",
    "vp",
    "vp_deficit",
    "rh_tmax",
    "rh_tmin"
]

# Growing season months (May–October)
GROW_MONTHS = [5, 6, 7, 8, 9, 10]

# --------------------------------------------------
# Process each yearly SILO file
# --------------------------------------------------
silo_files = sorted(glob.glob(f"{SILO_DIR}/*.nc"))

for f in silo_files:
    ds = xr.open_dataset(f)

    year = ds.time.dt.year.values[0]

    # Select growing season months
    ds_grow = ds.sel(
        time=ds.time.dt.month.isin(GROW_MONTHS)
    )[CLIMATE_VARS]

    # Sanity check
    assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"

    # Save
    out_file = f"{OUT_DIR}/silo_growing_season_{year}.nc"
    ds_grow.to_netcdf(out_file)

    print(f"✅ Saved growing season climate for {year}")
# Out:
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1991
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1992
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1993
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1994
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1995
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1996
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1997
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1998
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1999
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2000
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2001
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2002
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2003
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2004
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2005
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2006
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2007
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2008
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2009
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2010
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2011
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2012
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2013
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2014
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2015
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2016
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2017
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2018
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2019
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2020
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2021
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2022
# /tmp/ipython-input-4063261356.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2023

# %%
import xarray as xr

ds = xr.open_dataset(r"Data\raster\combined_climate_growing_season/silo_growing_season_2000.nc")
print(ds)
# Out:
# <xarray.Dataset> Size: 13MB
# Dimensions:       (time: 6, lat: 160, lon: 213)
# Coordinates:
#   * time          (time) datetime64[ns] 48B 2000-05-01 2000-06-01 ... 2000-10-01
#   * lat           (lat) float64 1kB -35.1 -35.05 -35.0 ... -27.25 -27.2 -27.15
#   * lon           (lon) float64 2kB 113.6 113.7 113.7 ... 124.1 124.2 124.2
# Data variables:
#     monthly_rain  (time, lat, lon) float64 2MB ...
#     max_temp      (time, lat, lon) float64 2MB ...
#     min_temp      (time, lat, lon) float64 2MB ...
#     radiation     (time, lat, lon) float64 2MB ...
#     vp            (time, lat, lon) float64 2MB ...
#     vp_deficit    (time, lat, lon) float64 2MB ...
#     rh_tmax       (time, lat, lon) float64 2MB ...
#     rh_tmin       (time, lat, lon) float64 2MB ...
# Attributes: (12/14)
#     department:               Department of Environment and Science
#     department_short:         DES
#     copyright:                Copyright - the State of Queensland Department ...
#     site_url:                 http://www.longpaddock.qld.gov.au
#     institution:              Queensland Government, Department of Environmen...
#     raster_source:            Gridded surface was created by interpolating ob...
#     ...                       ...
#     reference:                Jeffrey, S.J., Carter, J.O., Moodie, K.B.A. and...
#     disclaimer:               1. The user accepts all responsibility and risk...
#     title:                    Combined Climate Dataset
#     year:                     2000
#     source:                   SILO Climate Data
#     created_by:               xarray automated merge

# %%
import xarray as xr
import matplotlib.pyplot as plt
import geopandas as gpd

# === Load the shapefile for Queensland regions ===
shapefile_path = 'Eastern_Aus_Bunbury\Eastern_Aus_Bunbury.shp'
qld_shape = gpd.read_file(shapefile_path).to_crs("EPSG:4326")

# === Open the monthly max temperature data for QLD ===
ds = xr.open_dataset(r'Data\raster\combined_climate_growing_season\silo_growing_season_1991.nc')
monthly_rain = ds['monthly_rain']  # Adjust variable name as needed

# === Create figure and axes for the plot ===
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 12))
axes = axes.flatten()

# === Plot each month with its own colorbar ===
for i, month in enumerate(monthly_rain.time):
    ax = axes[i]
    data = monthly_rain.sel(time=month)

    # Plot with individual colorbar
    data.plot(ax=ax, cmap='cividis', add_colorbar=True)

    # Overlay region boundaries
    qld_shape.boundary.plot(ax=ax, color='black', linewidth=0.5, alpha=0.7)

    # Set the title
    ax.set_title(month.dt.strftime('%B').item())
    ax.set_xlabel('')
    ax.set_ylabel('')

# === Remove unused axes if any ===
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

# === Final layout ===
plt.tight_layout()
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\E'
# <>:6: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\u1171032\AppData\Local\Temp\ipykernel_15124\3477040807.py:6: SyntaxWarning: invalid escape sequence '\E'
#   shapefile_path = 'Eastern_Aus_Bunbury\Eastern_Aus_Bunbury.shp'

# %% [markdown]
# Drought growing monthsn

# %%
import xarray as xr
import glob
import os

# --------------------------------------------------
# Paths
# --------------------------------------------------
SILO_DIR = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/combined_drought_indices"
OUT_DIR  = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/combined_climate_growing_season/Drought_variables"
os.makedirs(OUT_DIR, exist_ok=True)

# Climate variables to keep
CLIMATE_VARS = [
    "spi_1",
    "spi_3",
    "spi_6",
    "spi_12",
    "spei_1",
    "spei_3",
    "spei_6",
    "spei_12"
]

# Growing season months (May–October)
GROW_MONTHS = [5, 6, 7, 8, 9, 10]

# --------------------------------------------------
# Process each yearly SILO file
# --------------------------------------------------
silo_files = sorted(glob.glob(f"{SILO_DIR}/*.nc"))

for f in silo_files:
    ds = xr.open_dataset(f)

    year = ds.time.dt.year.values[0]

    # Select growing season months
    ds_grow = ds.sel(
        time=ds.time.dt.month.isin(GROW_MONTHS)
    )[CLIMATE_VARS]

    # Sanity check
    assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"

    # Save
    out_file = f"{OUT_DIR}/drought_growing_season_{year}.nc"
    ds_grow.to_netcdf(out_file)

    print(f"✅ Saved growing season climate for {year}")
# Out:
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1991
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1992
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1993
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1994
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1995
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1996
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1997
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1998
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 1999
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2000
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2001
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2002
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2003
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2004
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2005
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2006
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2007
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2008
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2009
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2010
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2011
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2012
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2013
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2014
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2015
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2016
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2017
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2018
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2019
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2020
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2021
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2022
# /tmp/ipython-input-3893812321.py:43: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   assert ds_grow.dims["time"] == 6, f"Wrong months in {year}"
# ✅ Saved growing season climate for 2023

# %%
import xarray as xr

ds = xr.open_dataset(r"/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/combined_climate_growing_season/Drought_variables/drought_growing_season_1991.nc")
print(ds)
# Out:
# <xarray.Dataset> Size: 10MB
# Dimensions:  (time: 6, lat: 160, lon: 213)
# Coordinates:
#   * time     (time) datetime64[ns] 48B 1991-05-01 1991-06-01 ... 1991-10-01
#   * lat      (lat) float64 1kB -35.1 -35.05 -35.0 -34.95 ... -27.25 -27.2 -27.15
#   * lon      (lon) float64 2kB 113.6 113.7 113.7 113.8 ... 124.1 124.2 124.2
# Data variables:
#     spi_1    (time, lat, lon) float64 2MB ...
#     spi_3    (time, lat, lon) float64 2MB ...
#     spi_6    (time, lat, lon) float64 2MB ...
#     spi_12   (time, lat, lon) float64 2MB ...
#     spei_1   (time, lat, lon) float32 818kB ...
#     spei_3   (time, lat, lon) float32 818kB ...
#     spei_6   (time, lat, lon) float32 818kB ...
#     spei_12  (time, lat, lon) float32 818kB ...
# Attributes:
#     title:       Combined SPI and SPEI Dataset (All Timescales)
#     year:        1991
#     variables:   spi_1, spi_3, spi_6, spi_12, spei_1, spei_3, spei_6, spei_12
#     source:      Processed SPI/SPEI Data
#     created_by:  xarray automated merge

# %%
import xarray as xr
import matplotlib.pyplot as plt
import geopandas as gpd
from pathlib import Path

# === Load the shapefile ===
shapefile_path = r'/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Eastern_Aus_Bunbury/Eastern_Aus_Bunbury.shp'
qld_shape = gpd.read_file(shapefile_path).to_crs("EPSG:4326")

# === Open the SPI dataset ===
nc_path = Path(r'/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/combined_climate_growing_season/Drought_variables/drought_growing_season_1991.nc')
year = nc_path.stem.split('_')[1]

ds = xr.open_dataset(nc_path)

# === Select SPI variable ONCE ===
var_name = 'spei_1'          # change here: spi_3, spi_6, etc.
monthly_rain = ds[var_name]

# === Convert variable name to display label ===
spi_label = var_name.replace('_', '-').upper()   # spi_1 → SPI-1

# === Fix metadata so colorbar label is correct ===
monthly_rain.attrs.pop('units', None)
monthly_rain.attrs['long_name'] = spi_label

# === Create figure and axes ===
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))
axes = axes.flatten()

# === Plot each month ===
for i, month in enumerate(monthly_rain.time):
    ax = axes[i]
    data = monthly_rain.sel(time=month)

    data.plot(
        ax=ax,
        cmap='RdBu',
        add_colorbar=True
    )

    # Overlay region boundaries
    qld_shape.boundary.plot(
        ax=ax,
        color='black',
        linewidth=0.5,
        alpha=0.7
    )

    # Titles and formatting
    ax.set_title(month.dt.strftime('%B').item(), fontsize=11)
    ax.set_xlabel('')
    ax.set_ylabel('')

# === Remove unused subplots ===
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# === Figure title (automatic) ===
plt.suptitle(
    f'Monthly {spi_label} for {year} in WheatBelt',
    fontsize=16,
    y=0.98
)

plt.tight_layout()
plt.show()
