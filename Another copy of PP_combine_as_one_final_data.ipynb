# %%
import xarray as xr
import os
import numpy as np

# =====================================================
# PATHS
# =====================================================
# Update this to your NEW sequences folder
SEASONAL_DIR = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/seasonal_sequences"
YIELD_DIR    = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/rounded_farm"
OUTPUT_DIR   = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield"

os.makedirs(OUTPUT_DIR, exist_ok=True)

YEARS = range(1991, 2024)

for year in YEARS:
    print(f"🔄 Merging yield for {year}...")

    # 1. Load Data
    seasonal_ds = xr.open_dataset(os.path.join(SEASONAL_DIR, f"seasonal_features_{year}.nc"))
    yield_ds = xr.open_dataset(os.path.join(YIELD_DIR, f"wheat_farm_{year}.nc"))

    # 2. Identify Yield Variable
    if "H_wheat_dot_hat" in yield_ds.data_vars:
        yvar = "H_wheat_dot_hat"
    elif "wheat_yield" in yield_ds.data_vars:
        yvar = "wheat_yield"
    else:
        raise ValueError(f"No yield variable found in {year}")

    yield_da = yield_ds[yvar]

    # Drop time dim from yield if it exists (it should be static spatial map)
    if "time" in yield_da.dims:
        yield_da = yield_da.squeeze("time", drop=True)

    # =====================================================
    # 🛠️ THE FIX: COORDINATE ALIGNMENT
    # =====================================================
    print(f"   ...Aligning coordinates for {year}")

    # We force the Seasonal Data (Climate) to snap to the Yield Data's grid.
    # method='nearest' ensures we don't interpolate values, just pick the closest grid cell.
    # tolerance=0.01 protects us from matching far-away pixels if the grids are totally different.

    seasonal_aligned = seasonal_ds.interp(
        lat=yield_da.lat,
        lon=yield_da.lon,
        method="nearest"
    )

    # =====================================================
    # 3. Merge
    # =====================================================
    final_ds = xr.merge(
        [seasonal_aligned, yield_da.rename("yield")],
        compat="override" # Force merge since coords are now identical
    )

    # 4. Metadata & Save
    final_ds.attrs.update({
        "title": "Seasonal Climate Sequences & Yield (Aligned)",
        "year": year,
        "season": "May–October",
        "yield_type": "Annual wheat yield",
        "alignment_fix": "interp_nearest to yield grid"
    })

    out_file = os.path.join(OUTPUT_DIR, f"final_dataset_{year}.nc")
    final_ds.to_netcdf(out_file)

    print(f"✅ Saved {out_file}")

print("🎉 Stripes removed & Merged successfully!")
# Out:
# 🔄 Merging yield for 1991...
#    ...Aligning coordinates for 1991
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1991.nc
# 🔄 Merging yield for 1992...
#    ...Aligning coordinates for 1992
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1992.nc
# 🔄 Merging yield for 1993...
#    ...Aligning coordinates for 1993
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1993.nc
# 🔄 Merging yield for 1994...
#    ...Aligning coordinates for 1994
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1994.nc
# 🔄 Merging yield for 1995...
#    ...Aligning coordinates for 1995
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1995.nc
# 🔄 Merging yield for 1996...
#    ...Aligning coordinates for 1996
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1996.nc
# 🔄 Merging yield for 1997...
#    ...Aligning coordinates for 1997
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1997.nc
# 🔄 Merging yield for 1998...
#    ...Aligning coordinates for 1998
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1998.nc
# 🔄 Merging yield for 1999...
#    ...Aligning coordinates for 1999
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1999.nc
# 🔄 Merging yield for 2000...
#    ...Aligning coordinates for 2000
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2000.nc
# 🔄 Merging yield for 2001...
#    ...Aligning coordinates for 2001
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2001.nc
# 🔄 Merging yield for 2002...
#    ...Aligning coordinates for 2002
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2002.nc
# 🔄 Merging yield for 2003...
#    ...Aligning coordinates for 2003
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2003.nc
# 🔄 Merging yield for 2004...
#    ...Aligning coordinates for 2004
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2004.nc
# 🔄 Merging yield for 2005...
#    ...Aligning coordinates for 2005
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2005.nc
# 🔄 Merging yield for 2006...
#    ...Aligning coordinates for 2006
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2006.nc
# 🔄 Merging yield for 2007...
#    ...Aligning coordinates for 2007
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2007.nc
# 🔄 Merging yield for 2008...
#    ...Aligning coordinates for 2008
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2008.nc
# 🔄 Merging yield for 2009...
#    ...Aligning coordinates for 2009
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2009.nc
# 🔄 Merging yield for 2010...
#    ...Aligning coordinates for 2010
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2010.nc
# 🔄 Merging yield for 2011...
#    ...Aligning coordinates for 2011
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2011.nc
# 🔄 Merging yield for 2012...
#    ...Aligning coordinates for 2012
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2012.nc
# 🔄 Merging yield for 2013...
#    ...Aligning coordinates for 2013
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2013.nc
# 🔄 Merging yield for 2014...
#    ...Aligning coordinates for 2014
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2014.nc
# 🔄 Merging yield for 2015...
#    ...Aligning coordinates for 2015
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2015.nc
# 🔄 Merging yield for 2016...
#    ...Aligning coordinates for 2016
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2016.nc
# 🔄 Merging yield for 2017...
#    ...Aligning coordinates for 2017
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2017.nc
# 🔄 Merging yield for 2018...
#    ...Aligning coordinates for 2018
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2018.nc
# 🔄 Merging yield for 2019...
#    ...Aligning coordinates for 2019
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2019.nc
# 🔄 Merging yield for 2020...
#    ...Aligning coordinates for 2020
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2020.nc
# 🔄 Merging yield for 2021...
#    ...Aligning coordinates for 2021
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2021.nc
# 🔄 Merging yield for 2022...
#    ...Aligning coordinates for 2022
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2022.nc
# 🔄 Merging yield for 2023...
#    ...Aligning coordinates for 2023
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_2023.nc
# 🎉 Stripes removed & Merged successfully!

# %%
import xarray as xr
import matplotlib.pyplot as plt
import geopandas as gpd
from pathlib import Path

# === Load the shapefile ===
shapefile_path = r'/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Eastern_Aus_Bunbury/Eastern_Aus_Bunbury.shp'
qld_shape = gpd.read_file(shapefile_path).to_crs("EPSG:4326")

# === Open the SPI dataset ===
nc_path = Path(r'/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_sequence_with_yield/final_dataset_1991.nc')
year = nc_path.stem.split('_')[1]

ds = xr.open_dataset(nc_path)

# === Select SPI variable ONCE ===
var_name = 'max_temp'          # change here: spi_3, spi_6, etc.
monthly_rain = ds[var_name]

# === Convert variable name to display label ===
spi_label = var_name.replace('_', '-').upper()   # spi_1 → SPI-1

# === Fix metadata so colorbar label is correct ===
monthly_rain.attrs.pop('units', None)
monthly_rain.attrs['long_name'] = spi_label

# === Create figure and axes ===
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 12))
axes = axes.flatten()

# === Plot each month ===
for i, month in enumerate(monthly_rain.time):
    ax = axes[i]
    data = monthly_rain.sel(time=month)

    data.plot(
        ax=ax,
        cmap='RdBu',
        add_colorbar=True
    )

    # Overlay region boundaries
    qld_shape.boundary.plot(
        ax=ax,
        color='black',
        linewidth=0.5,
        alpha=0.7
    )

    # Titles and formatting
    ax.set_title(month.dt.strftime('%B').item(), fontsize=11)
    ax.set_xlabel('')
    ax.set_ylabel('')

# === Remove unused subplots ===
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# === Figure title (automatic) ===
plt.suptitle(
    f'Monthly {spi_label} for {year} in WheatBelt',
    fontsize=16,
    y=0.98
)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import xarray as xr

# Load one merged file
ds = xr.open_dataset("/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1995.nc")

# Plot Yield
plt.figure(figsize=(20, 12))
ds['yield'].plot(cmap='viridis')
plt.title("Yield Map (Check if this looks distorted)")
plt.show()
