# %% [markdown]
# All variables

# %%
import xarray as xr
import os
from glob import glob

# =====================================================
# CONFIGURATION
# =====================================================

INPUT_DIR = r"Data\raster\EA_Selected_Farm_Data"
OUTPUT_DIR = r"Data\raster\rounded_climate"

os.makedirs(OUTPUT_DIR, exist_ok=True)

# =====================================================
# PROCESS FILES
# =====================================================

nc_files = glob(os.path.join(INPUT_DIR, "*.nc"))

print(f"Found {len(nc_files)} NetCDF files")

for nc_file in nc_files:
    filename = os.path.basename(nc_file)

    # -------------------------------------------------
    # Extract year from 'cYYYY'
    # -------------------------------------------------
    parts = filename.split(".")
    c_part = next(p for p in parts if p.startswith("c") and p[1:].isdigit())
    year = c_part[1:]   # remove 'c'

    # -------------------------------------------------
    # New filename
    # -------------------------------------------------
    new_filename = f"wheat_farm_{year}.nc"
    out_path = os.path.join(OUTPUT_DIR, new_filename)

    print(f"🔄 {filename} → {new_filename}")

    # -------------------------------------------------
    # Open, process (optional), save
    # -------------------------------------------------
    ds = xr.open_dataset(nc_file)

    # (Optional) round coords again if needed
    ds = ds.assign_coords(
        lat=ds.lat.round(2),
        lon=ds.lon.round(2)
    )

    ds.to_netcdf(out_path)
    ds.close()

    print(f"✅ Saved → {out_path}")

print("🎉 All files renamed and saved successfully!")
# Out:
# Found 33 NetCDF files
# 🔄 f2022.c1991.p2022.t2022_cropped.nc → wheat_farm_1991.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1991.nc
# 🔄 f2022.c1992.p2022.t2022_cropped.nc → wheat_farm_1992.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1992.nc
# 🔄 f2022.c1993.p2022.t2022_cropped.nc → wheat_farm_1993.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1993.nc
# 🔄 f2022.c1994.p2022.t2022_cropped.nc → wheat_farm_1994.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1994.nc
# 🔄 f2022.c1995.p2022.t2022_cropped.nc → wheat_farm_1995.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1995.nc
# 🔄 f2022.c1996.p2022.t2022_cropped.nc → wheat_farm_1996.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1996.nc
# 🔄 f2022.c1997.p2022.t2022_cropped.nc → wheat_farm_1997.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1997.nc
# 🔄 f2022.c1998.p2022.t2022_cropped.nc → wheat_farm_1998.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1998.nc
# 🔄 f2022.c1999.p2022.t2022_cropped.nc → wheat_farm_1999.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1999.nc
# 🔄 f2022.c2000.p2022.t2022_cropped.nc → wheat_farm_2000.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2000.nc
# 🔄 f2022.c2001.p2022.t2022_cropped.nc → wheat_farm_2001.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2001.nc
# 🔄 f2022.c2002.p2022.t2022_cropped.nc → wheat_farm_2002.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2002.nc
# 🔄 f2022.c2003.p2022.t2022_cropped.nc → wheat_farm_2003.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2003.nc
# 🔄 f2022.c2004.p2022.t2022_cropped.nc → wheat_farm_2004.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2004.nc
# 🔄 f2022.c2005.p2022.t2022_cropped.nc → wheat_farm_2005.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2005.nc
# 🔄 f2022.c2006.p2022.t2022_cropped.nc → wheat_farm_2006.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2006.nc
# 🔄 f2022.c2007.p2022.t2022_cropped.nc → wheat_farm_2007.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2007.nc
# 🔄 f2022.c2008.p2022.t2022_cropped.nc → wheat_farm_2008.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2008.nc
# 🔄 f2022.c2009.p2022.t2022_cropped.nc → wheat_farm_2009.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2009.nc
# 🔄 f2022.c2010.p2022.t2022_cropped.nc → wheat_farm_2010.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2010.nc
# 🔄 f2022.c2011.p2022.t2022_cropped.nc → wheat_farm_2011.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2011.nc
# 🔄 f2022.c2012.p2022.t2022_cropped.nc → wheat_farm_2012.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2012.nc
# 🔄 f2022.c2013.p2022.t2022_cropped.nc → wheat_farm_2013.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2013.nc
# 🔄 f2022.c2014.p2022.t2022_cropped.nc → wheat_farm_2014.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2014.nc
# 🔄 f2022.c2015.p2022.t2022_cropped.nc → wheat_farm_2015.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2015.nc
# 🔄 f2022.c2016.p2022.t2022_cropped.nc → wheat_farm_2016.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2016.nc
# 🔄 f2022.c2017.p2022.t2022_cropped.nc → wheat_farm_2017.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2017.nc
# 🔄 f2022.c2018.p2022.t2022_cropped.nc → wheat_farm_2018.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2018.nc
# 🔄 f2022.c2019.p2022.t2022_cropped.nc → wheat_farm_2019.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2019.nc
# 🔄 f2022.c2020.p2022.t2022_cropped.nc → wheat_farm_2020.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2020.nc
# 🔄 f2022.c2021.p2022.t2022_cropped.nc → wheat_farm_2021.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2021.nc
# 🔄 f2022.c2022.p2022.t2022_cropped.nc → wheat_farm_2022.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2022.nc
# 🔄 f2022.c2023.p2022.t2022_cropped.nc → wheat_farm_2023.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2023.nc
# 🎉 All files renamed and saved successfully!

# %% [markdown]
# Target Variable

# %%
import xarray as xr
import os
from glob import glob

# =====================================================
# CONFIGURATION
# =====================================================

INPUT_DIR = r"Data\raster\EA_Selected_Farm_Data"
OUTPUT_DIR = r"Data\raster\rounded_climate"

TARGET_VAR = "H_wheat_dot_hat"

os.makedirs(OUTPUT_DIR, exist_ok=True)

# =====================================================
# PROCESS FILES
# =====================================================

nc_files = glob(os.path.join(INPUT_DIR, "*.nc"))

print(f"Found {len(nc_files)} NetCDF files")

for nc_file in nc_files:
    filename = os.path.basename(nc_file)

    # -------------------------------------------------
    # Extract year from 'cYYYY'
    # -------------------------------------------------
    parts = filename.split(".")
    c_part = next(
        p for p in parts if p.startswith("c") and p[1:].isdigit()
    )
    year = c_part[1:]   # remove 'c'

    new_filename = f"wheat_farm_{year}.nc"
    out_path = os.path.join(OUTPUT_DIR, new_filename)

    print(f"🔄 {filename} → {new_filename}")

    # -------------------------------------------------
    # Open dataset
    # -------------------------------------------------
    ds = xr.open_dataset(nc_file)

    # -------------------------------------------------
    # Safety check
    # -------------------------------------------------
    if TARGET_VAR not in ds:
        print(f"⚠️ Skipping {filename} (missing {TARGET_VAR})")
        ds.close()
        continue

    # -------------------------------------------------
    # Keep ONLY wheat variable
    # -------------------------------------------------
    wheat_ds = ds[[TARGET_VAR]]

    # Round coordinates (recommended)
    wheat_ds = wheat_ds.assign_coords(
        lat=wheat_ds.lat.round(2),
        lon=wheat_ds.lon.round(2)
    )

    # -------------------------------------------------
    # Save cleaned NetCDF
    # -------------------------------------------------
    wheat_ds.to_netcdf(out_path)

    ds.close()
    wheat_ds.close()

    print(f"✅ Saved → {out_path}")

print("🎉 All wheat-only NetCDF files created successfully!")
# Out:
# Found 33 NetCDF files
# 🔄 f2022.c1991.p2022.t2022_cropped.nc → wheat_farm_1991.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1991.nc
# 🔄 f2022.c1992.p2022.t2022_cropped.nc → wheat_farm_1992.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1992.nc
# 🔄 f2022.c1993.p2022.t2022_cropped.nc → wheat_farm_1993.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1993.nc
# 🔄 f2022.c1994.p2022.t2022_cropped.nc → wheat_farm_1994.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1994.nc
# 🔄 f2022.c1995.p2022.t2022_cropped.nc → wheat_farm_1995.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1995.nc
# 🔄 f2022.c1996.p2022.t2022_cropped.nc → wheat_farm_1996.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1996.nc
# 🔄 f2022.c1997.p2022.t2022_cropped.nc → wheat_farm_1997.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1997.nc
# 🔄 f2022.c1998.p2022.t2022_cropped.nc → wheat_farm_1998.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1998.nc
# 🔄 f2022.c1999.p2022.t2022_cropped.nc → wheat_farm_1999.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_1999.nc
# 🔄 f2022.c2000.p2022.t2022_cropped.nc → wheat_farm_2000.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2000.nc
# 🔄 f2022.c2001.p2022.t2022_cropped.nc → wheat_farm_2001.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2001.nc
# 🔄 f2022.c2002.p2022.t2022_cropped.nc → wheat_farm_2002.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2002.nc
# 🔄 f2022.c2003.p2022.t2022_cropped.nc → wheat_farm_2003.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2003.nc
# 🔄 f2022.c2004.p2022.t2022_cropped.nc → wheat_farm_2004.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2004.nc
# 🔄 f2022.c2005.p2022.t2022_cropped.nc → wheat_farm_2005.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2005.nc
# 🔄 f2022.c2006.p2022.t2022_cropped.nc → wheat_farm_2006.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2006.nc
# 🔄 f2022.c2007.p2022.t2022_cropped.nc → wheat_farm_2007.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2007.nc
# 🔄 f2022.c2008.p2022.t2022_cropped.nc → wheat_farm_2008.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2008.nc
# 🔄 f2022.c2009.p2022.t2022_cropped.nc → wheat_farm_2009.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2009.nc
# 🔄 f2022.c2010.p2022.t2022_cropped.nc → wheat_farm_2010.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2010.nc
# 🔄 f2022.c2011.p2022.t2022_cropped.nc → wheat_farm_2011.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2011.nc
# 🔄 f2022.c2012.p2022.t2022_cropped.nc → wheat_farm_2012.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2012.nc
# 🔄 f2022.c2013.p2022.t2022_cropped.nc → wheat_farm_2013.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2013.nc
# 🔄 f2022.c2014.p2022.t2022_cropped.nc → wheat_farm_2014.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2014.nc
# 🔄 f2022.c2015.p2022.t2022_cropped.nc → wheat_farm_2015.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2015.nc
# 🔄 f2022.c2016.p2022.t2022_cropped.nc → wheat_farm_2016.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2016.nc
# 🔄 f2022.c2017.p2022.t2022_cropped.nc → wheat_farm_2017.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2017.nc
# 🔄 f2022.c2018.p2022.t2022_cropped.nc → wheat_farm_2018.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2018.nc
# 🔄 f2022.c2019.p2022.t2022_cropped.nc → wheat_farm_2019.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2019.nc
# 🔄 f2022.c2020.p2022.t2022_cropped.nc → wheat_farm_2020.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2020.nc
# 🔄 f2022.c2021.p2022.t2022_cropped.nc → wheat_farm_2021.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2021.nc
# 🔄 f2022.c2022.p2022.t2022_cropped.nc → wheat_farm_2022.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2022.nc
# 🔄 f2022.c2023.p2022.t2022_cropped.nc → wheat_farm_2023.nc
# ✅ Saved → Data\raster\rounded_climate\wheat_farm_2023.nc
# 🎉 All wheat-only NetCDF files created successfully!
