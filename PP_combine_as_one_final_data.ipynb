# %%
import xarray as xr
import os

SEASONAL_DIR = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/seasonal_aggregated"
YIELD_DIR    = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/rounded_farm"
OUTPUT_DIR   = "/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield"

os.makedirs(OUTPUT_DIR, exist_ok=True)

YEARS = range(1991, 2024)

# %%
for year in YEARS:
    print(f"🔄 Merging yield for {year}")

    # -------------------------------------------------
    # Load seasonal features
    # -------------------------------------------------
    seasonal_ds = xr.open_dataset(
        os.path.join(SEASONAL_DIR, f"seasonal_features_{year}.nc")
    )

    # -------------------------------------------------
    # Load yield
    # -------------------------------------------------
    yield_ds = xr.open_dataset(
        os.path.join(YIELD_DIR, f"wheat_farm_{year}.nc")
    )

    # -------------------------------------------------
    # Identify yield variable safely
    # -------------------------------------------------
    if "H_wheat_dot_hat" in yield_ds.data_vars:
        yvar = "H_wheat_dot_hat"
    elif "wheat_yield" in yield_ds.data_vars:
        yvar = "wheat_yield"
    else:
        raise ValueError(f"No yield variable found in {year}")

    # -------------------------------------------------
    # Ensure yield has no time dimension
    # (annual → spatial only)
    # -------------------------------------------------
    if "time" in yield_ds[yvar].dims:
        yield_da = yield_ds[yvar].squeeze("time", drop=True)
    else:
        yield_da = yield_ds[yvar]

    # -------------------------------------------------
    # Merge seasonal + yield
    # -------------------------------------------------
    final_ds = xr.merge(
        [seasonal_ds, yield_da.rename("yield")],
        compat="no_conflicts"
    )

    # -------------------------------------------------
    # Metadata
    # -------------------------------------------------
    final_ds.attrs.update({
        "title": "Seasonal Climate, Drought Indices, and Wheat Yield",
        "year": year,
        "season": "May–October",
        "yield_type": "Annual wheat yield",
        "created_by": "xarray seasonal-yield merge"
    })

    # -------------------------------------------------
    # Save
    # -------------------------------------------------
    out_file = os.path.join(OUTPUT_DIR, f"final_dataset_{year}.nc")
    final_ds.to_netcdf(out_file)

    print(f"✅ Saved {out_file}")

print("🎉 Yield merged successfully for all years!")
# Out:
# 🔄 Merging yield for 1991
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1991.nc
# 🔄 Merging yield for 1992
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1992.nc
# 🔄 Merging yield for 1993
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1993.nc
# 🔄 Merging yield for 1994
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1994.nc
# 🔄 Merging yield for 1995
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1995.nc
# 🔄 Merging yield for 1996
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1996.nc
# 🔄 Merging yield for 1997
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1997.nc
# 🔄 Merging yield for 1998
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1998.nc
# 🔄 Merging yield for 1999
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1999.nc
# 🔄 Merging yield for 2000
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2000.nc
# 🔄 Merging yield for 2001
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2001.nc
# 🔄 Merging yield for 2002
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2002.nc
# 🔄 Merging yield for 2003
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2003.nc
# 🔄 Merging yield for 2004
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2004.nc
# 🔄 Merging yield for 2005
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2005.nc
# 🔄 Merging yield for 2006
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2006.nc
# 🔄 Merging yield for 2007
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2007.nc
# 🔄 Merging yield for 2008
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2008.nc
# 🔄 Merging yield for 2009
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2009.nc
# 🔄 Merging yield for 2010
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2010.nc
# 🔄 Merging yield for 2011
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2011.nc
# 🔄 Merging yield for 2012
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2012.nc
# 🔄 Merging yield for 2013
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2013.nc
# 🔄 Merging yield for 2014
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2014.nc
# 🔄 Merging yield for 2015
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2015.nc
# 🔄 Merging yield for 2016
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2016.nc
# 🔄 Merging yield for 2017
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2017.nc
# 🔄 Merging yield for 2018
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2018.nc
# 🔄 Merging yield for 2019
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2019.nc
# 🔄 Merging yield for 2020
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2020.nc
# 🔄 Merging yield for 2021
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2021.nc
# 🔄 Merging yield for 2022
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2022.nc
# 🔄 Merging yield for 2023
# /tmp/ipython-input-2509619365.py:40: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',) The recommendation is to set join explicitly for this case.
#   final_ds = xr.merge(
# ✅ Saved /content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_2023.nc
# 🎉 Yield merged successfully for all years!

# %%
ds = xr.open_dataset("/content/drive/MyDrive/Research Works - Development/Work 2 - SPI SPEI/Data/raster/Data for Dev/final_with_yield/final_dataset_1991.nc")
print(ds)
# Out:
# <xarray.Dataset> Size: 5MB
# Dimensions:             (lat: 179, lon: 213)
# Coordinates:
#   * lat                 (lat) float64 1kB -35.1 -35.05 -35.0 ... -27.2 -27.15
#   * lon                 (lon) float64 2kB 113.6 113.7 113.7 ... 124.2 124.2
# Data variables: (12/17)
#     monthly_rain_MJJAO  (lat, lon) float64 305kB ...
#     max_temp_MJJAO      (lat, lon) float64 305kB ...
#     min_temp_MJJAO      (lat, lon) float64 305kB ...
#     radiation_MJJAO     (lat, lon) float64 305kB ...
#     vp_MJJAO            (lat, lon) float64 305kB ...
#     vp_deficit_MJJAO    (lat, lon) float64 305kB ...
#     ...                  ...
#     spi_12_MJJAO        (lat, lon) float64 305kB ...
#     spei_1_MJJAO        (lat, lon) float32 153kB ...
#     spei_3_MJJAO        (lat, lon) float32 153kB ...
#     spei_6_MJJAO        (lat, lon) float32 153kB ...
#     spei_12_MJJAO       (lat, lon) float32 153kB ...
#     yield               (lat, lon) float64 305kB ...
# Attributes:
#     title:        Seasonal Climate, Drought Indices, and Wheat Yield
#     year:         1991
#     aggregation:  Rain=sum, others=mean, SPI/SPEI=mean
#     season:       May–October
#     created_by:   xarray seasonal-yield merge
#     yield_type:   Annual wheat yield
